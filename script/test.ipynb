# %%
import os
for i,j,k in os.walk("."):
    print(i,j,k)
# Out:
# . [] ['company_detector.py', 'deepl_glossary.py', 'deepl_translate.py', 'generate_links.py', 'Main Page.html', 'main.py', 'New Player Missions.html', 'table_html2md.py', 'test.csv', 'test.html', 'test.ipynb', 'test_glossary.txt', 'wiki_crawler.py']

# %%
import pandas as pd
df = pd.read_csv("test.csv")
df
# Out:
#    序号         日期 Training Contract Protection Contract Engagement Contract  \
# 0   1  2023/1/16           500,000           3,000,000           8,000,000
# 1   2  2023/1/17           500,000           3,000,000           7,000,000
# 2   3  2023/1/18           500,000           3,000,000           8,000,000
# 3   4  2023/1/19           500,000           3,000,000           8,000,000
# 4   5  2023/1/20           500,000           3,000,000           8,000,000
# 5   6  2023/1/21           500,000           3,000,000           8,000,000
# 6   7  2023/1/22           500,000           3,000,000           8,000,000
# 7   8  2023/1/23           500,000           3,000,000           8,000,000
# 8   9  2023/1/24           500,000           3,000,000           8,000,000
#
#   Military Contract  生产日期         收入            工资          广告费         利润  \
# 0        15,000,000     1  2023/1/16   $4,000,000   $2,774,000   $501,101
# ...

# %%
df["日期"].loc[1]
# Out:
# '2023/1/17'

# %%
import datetime
now = datetime.datetime.now()

# %%
a = df[df["日期"]=="2023/1/17"].index[0]

# %%
df.shape
# Out:
# (9, 19)
